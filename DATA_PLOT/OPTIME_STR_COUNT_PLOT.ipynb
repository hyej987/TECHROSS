# %% [markdown]
# <a href="https://colab.research.google.com/github/hyej987/TECHROSS/blob/master/DATA_PLOT/OPTIME_STR_COUNT_PLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OPTIME 테이블 범주형 자료 바 플랏 그리기
# - OPTIME 테이블에는 총 11개의 범주형 변수가 존재
# - OP_TYPE, LINE, NORMAL, LATITUDE, LONGITUDE, ALARM_COUNT, FAULT_CODE, MODE, SECTION, REGION_ID, STATE

# %% [markdown]
# # 패키지로딩

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install sidetable
import sidetable
# %matplotlib inline
# Out:
# Mounted at /content/gdrive
# Collecting sidetable
#   Downloading sidetable-0.9.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.7/dist-packages (from sidetable) (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0->sidetable) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->sidetable) (1.15.0)
# Installing collected packages: sidetable
# Successfully installed sidetable-0.9.0

# %% [markdown]
# # 데이터 로딩

# %%
EVENT = pd.read_csv('/content/gdrive/MyDrive/DB/OPTIME.csv')
list_event = ['OP_TYPE', 'LINE', 'NORMAL', 'LATITUDE', 'LONGITUDE', 'ALARM_COUNT', 'FAULT_CODE', 'MODE', 'SECTION', 'REGION_ID', 'STATE']
for i in range(len(list_event)) :
 EVENT[f'{list_event[i]}']=EVENT[f'{list_event[i]}'].astype(str)

# %% [markdown]
# # 100% 플랏

# %%
list_event_data = []

for i in range(len(list_event)) :
  list_event_data.append(pd.DataFrame(EVENT[f"{list_event[i]}"].dropna().value_counts()))

for i in range(len(list_event)) :
  list_event_data[i] = list_event_data[i][list_event_data[i].index != 'nan']

for i in range(len(list_event)) :
  plt.figure(figsize = (30,10))
  plt.bar(list_event_data[i].index, list_event_data[i][f'{list_event[i]}'])
  plt.xticks(rotation = 90)
  plt.title('OPTIME TABLE' +"     " +f'{list_event[i]}',fontsize = 20, pad = 20)
  plt.savefig('/content/gdrive/MyDrive/OPTIME/' + f'{list_event[i]}' + ".png")

# %% [markdown]
# # 90% 플랏

# %%
list_event_data_90 = []

for i in range(len(list_event)) :
  list_event_data_90.append(list_event_data[i].reset_index().stb.freq(['index'], value = f'{list_event[i]}', thresh = 90)[["index","percent"]])

for i in range(len(list_event)) :
  plt.figure(figsize = (30,10))
  plt.bar(list_event_data_90[i].iloc[:,0], list_event_data_90[i].iloc[:,1])
  plt.xticks(rotation = 90)
  plt.title('OPTIME TABLE' +"     " +f'{list_event[i]}'+ "      " + "90%",fontsize = 20, pad = 20)
  plt.savefig('/content/gdrive/MyDrive/OPTIME/' + f'{list_event[i]}' +"   90%" +".png")
# Out:
# /usr/local/lib/python3.7/dist-packages/sidetable/sidetable.py:138: RuntimeWarning: invalid value encountered in long_scalars
#   other_pct = (other_total / total) * 100

# %% [markdown]
# # 80% 플랏

# %%
list_event_80 = []

for i in range(len(list_event)) :
  list_event_80.append(list_event_data[i].reset_index().stb.freq(['index'], value = f'{list_event[i]}', thresh = 50)[["index","percent"]])

for i in range(len(list_event)) :
  plt.figure(figsize = (30,10))
  plt.bar(list_event_80[i].iloc[:,0], list_event_80[i].iloc[:,1])
  plt.xticks(rotation = 90)
  plt.title('OPTIME TABLE' +"     " +f'{list_event[i]}'+ "      " + "80%",fontsize = 20, pad = 20)
  plt.savefig('/content/gdrive/MyDrive/OPTIME/' + f'{list_event[i]}' +"   80%" +".png")
# Out:
# /usr/local/lib/python3.7/dist-packages/sidetable/sidetable.py:138: RuntimeWarning: invalid value encountered in long_scalars
#   other_pct = (other_total / total) * 100

# %% [markdown]
# # 50% 플랏

# %%
list_event_data_50 = []

for i in range(len(list_event)) :
  list_event_data_50.append(list_event_data[i].reset_index().stb.freq(['index'], value = f'{list_event[i]}', thresh = 50)[["index","percent"]])

for i in range(len(list_event)) :
  plt.figure(figsize = (30,10))
  plt.bar(list_event_data_50[i].iloc[:,0], list_event_data_50[i].iloc[:,1])
  plt.xticks(rotation = 90)
  plt.title('OPTIME TABLE' +"     " +f'{list_event[i]}'+ "      " + "50%",fontsize = 20, pad = 20)
  plt.savefig('/content/gdrive/MyDrive/OPTIME/' + f'{list_event[i]}' +"   50%" +".png")
# Out:
# /usr/local/lib/python3.7/dist-packages/sidetable/sidetable.py:138: RuntimeWarning: invalid value encountered in long_scalars
#   other_pct = (other_total / total) * 100
