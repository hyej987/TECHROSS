# %% [markdown]
# <a href="https://colab.research.google.com/github/hyej987/TECHROSS/blob/master/NEW_DB/PREPROCESSING_DATA_MACHINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 전처리 머신
#
# - 자동 전처리 기능 지원
# - 3 오퍼레이션까지 라벨링 가능

# %%
print("주의사항")
print("폴더 안의 파일이름이 제시되는 질문의 파일 이름과 모두 같고, 확장자는 csv 파일이어야 합니다.")
print("colab 환경이십니까? : yes/no")
colab = input()
if colab == 'yes' :
    print('코랩 로딩중...')
    from google.colab import drive
    drive.mount('/content/gdrive')
else :
    pass
print("호선의 ID를 입력하세요")
SHIP_ID = input()
print("몇번째 SECTION입니까?")
SECTION = int(input())

# 파일 이름 마음대로 지었을 때
#print("DATA의 경로를 입력하세요")
#DATA_LOAD = input()
#print("EVENT의 경로를 입력하세요")
#EVENT_LOAD = input()
#print("OPTIME의 경로를 입력하세요")
#OPTIME_LOAD = input()
#print("DATA_DEVICE의 경로를 입력하세요")
#DATA_DEVICE_LOAD = input()
#print("OPTIME_EVENT의 경로를 입력하세요")
#OPTIME_EVENT_LOAD = input()
#print("ANU의 경로를 입력하세요")
#ANU_LOAD = input()
#print("TSU의 경로를 입력하세요")
#TSU_LOAD = input()
#print("PMU의 경로를 입력하세요")
#PMU_LOAD = input()
#print("ECU의 경로를 입력하세요")
#ECU_LOAD = input()
# 여기서부터 시작
#ANU = pd.read_csv(ANU_LOAD)
#PMU = pd.read_csv(PMU_LOAD)
#TSU = pd.read_csv(TSU_LOAD)
#ECU = pd.read_csv(ECU_LOAD)
#DATA = pd.read_csv(DATA_LOAD)
#EVENT = pd.read_csv(EVENT_LOAD)
#OPTIME = pd.read_csv(OPTIME_LOAD)
#DATA_DEVICE = pd.read_csv(DATA_DEVICE_LOAD)
#OPTIME_EVENT = pd.read_csv(OPTIME_EVENT_LOAD)


dir = input("폴더 경로를 입력하세요 : ")
import pandas as pd
print("데이터 로딩중")
ANU = pd.read_csv(dir + '/ANU.csv')
PMU = pd.read_csv(dir + '/PMU.csv')
TSU = pd.read_csv(dir + '/TSU.csv')
ECU = pd.read_csv(dir + '/ECU.csv')
DATA = pd.read_csv(dir + '/DATA.csv')
EVENT = pd.read_csv(dir + '/EVENT.csv')
OPTIME = pd.read_csv(dir + '/OPTIME.csv')
DATA_DEVICE = pd.read_csv(dir + '/DATA_DEVICE.csv')
OPTIME_EVENT = pd.read_csv(dir + '/OPTIME_EVENT.csv')


import time
start_time = time.time()

print("패키지를 로딩할게요")

import numpy as np
import warnings
warnings.filterwarnings('ignore')


ANU = ANU[(ANU['SHIP_ID'] == SHIP_ID) & (ANU['SECTION'] == SECTION)]
PMU = PMU[(PMU['SHIP_ID'] == SHIP_ID) & (PMU['SECTION'] == SECTION)]
TSU = TSU[(TSU['SHIP_ID'] == SHIP_ID) & (TSU['SECTION'] == SECTION)]
ECU = ECU[(ECU['SHIP_ID'] == SHIP_ID) & (ECU['SECTION'] == SECTION)]
DATA = DATA[(DATA['SHIP_ID'] == SHIP_ID) & (DATA['SECTION'] == SECTION)]
EVENT = EVENT[(EVENT['SHIP_ID'] == SHIP_ID) & (EVENT['SECTION'] == SECTION)]
OPTIME = OPTIME[(OPTIME['SHIP_ID'] == SHIP_ID) & (OPTIME['SECTION'] == SECTION)]
DATA_DEVICE = DATA_DEVICE[(DATA_DEVICE['SHIP_ID'] == SHIP_ID) & (DATA_DEVICE['SECTION'] == SECTION)]
OPTIME_EVENT = OPTIME_EVENT[(OPTIME_EVENT['SHIP_ID'] == SHIP_ID) & (OPTIME_EVENT['SECTION'] == SECTION)]

ECU_COL = ECU.columns
ANU_COL = ANU.columns
TSU_COL = TSU.columns
PMU_COL = PMU.columns
##################################################################################

############## THIS IS LONG ######################################################

##################################################################################


ECU['DDKEY'] = ECU['SHIP_ID'] + "_" + ECU['SECTION'].astype(str) + "_" + ECU['D_INDEX'].astype(str) + "_" + ECU['DEVICE_ID'].astype(str)
ANU['DDKEY'] = ANU['SHIP_ID'] + "_" + ANU['SECTION'].astype(str) + "_" + ANU['D_INDEX'].astype(str) + "_" + ANU['DEVICE_ID'].astype(str)
TSU['DDKEY'] = TSU['SHIP_ID'] + "_" + TSU['SECTION'].astype(str) + "_" + TSU['D_INDEX'].astype(str) + "_" + TSU['DEVICE_ID'].astype(str)
PMU['DDKEY'] = PMU['SHIP_ID'] + "_" + PMU['SECTION'].astype(str) + "_" + PMU['D_INDEX'].astype(str) + "_" + PMU['DEVICE_ID'].astype(str)
DATA_DEVICE['DDKEY'] = DATA_DEVICE['SHIP_ID'] + "_" + DATA_DEVICE['SECTION'].astype(str) + "_" + DATA_DEVICE['D_INDEX'].astype(str) + "_" + DATA_DEVICE['DEVICE_ID'].astype(str)


DATA_DEVICE_ECU=DATA_DEVICE.loc[DATA_DEVICE['DEVICETYPE']==1,:]
DATA_DEVICE_ANU=DATA_DEVICE.loc[DATA_DEVICE['DEVICETYPE']==2,:]
DATA_DEVICE_TSU=DATA_DEVICE.loc[DATA_DEVICE['DEVICETYPE']==3,:]
DATA_DEVICE_PMU=DATA_DEVICE.loc[DATA_DEVICE['DEVICETYPE']==4,:]


DDECU = pd.merge(ECU,DATA_DEVICE_ECU, how = 'left', on = 'DDKEY')
DDECU=DDECU.drop(columns = ['DEVICE_ID_y','D_INDEX_y','SHIP_ID_y','SECTION_y','DDKEY'])
DDECU=DDECU.rename(columns = {'SHIP_ID_x' : 'SHIP_ID', 'D_INDEX_x' : 'D_INDEX', 'DEVICE_ID_x' : 'DEVICE_ID',  'SECTION_x':'SECTION'})

DDANU = pd.merge(ANU,DATA_DEVICE_ANU, how = 'left', on = 'DDKEY')
DDANU=DDANU.drop(columns = ['DEVICE_ID_y','D_INDEX_y','SHIP_ID_y','SECTION_y','DDKEY'])
DDANU=DDANU.rename(columns = {'SHIP_ID_x' : 'SHIP_ID', 'D_INDEX_x' : 'D_INDEX', 'DEVICE_ID_x' : 'DEVICE_ID',  'SECTION_x':'SECTION'})

DDPMU = pd.merge(PMU,DATA_DEVICE_PMU, how = 'left', on = 'DDKEY')
DDPMU=DDPMU.drop(columns = ['DEVICE_ID_y','D_INDEX_y','SHIP_ID_y','SECTION_y','DDKEY'])
DDPMU=DDPMU.rename(columns = {'SHIP_ID_x' : 'SHIP_ID', 'D_INDEX_x' : 'D_INDEX', 'DEVICE_ID_x' : 'DEVICE_ID',  'SECTION_x':'SECTION'})

DDTSU = pd.merge(TSU,DATA_DEVICE_TSU, how = 'left', on = 'DDKEY')
DDTSU=DDTSU.drop(columns = ['DEVICE_ID_y','D_INDEX_y','SHIP_ID_y','SECTION_y','DDKEY'])
DDTSU=DDTSU.rename(columns = {'SHIP_ID_x' : 'SHIP_ID', 'D_INDEX_x' : 'D_INDEX', 'DEVICE_ID_x' : 'DEVICE_ID',  'SECTION_x':'SECTION'})


DDECU_1 = DDECU.loc[DDECU['DEVICE_ID'] == 1,:]
DDECU_1['KEY']=DDECU_1['SHIP_ID'] + "_" + DDECU_1['SECTION'].astype(str) + "_" + DDECU_1['OP_INDEX'].astype(str) + "_" + DDECU_1['DATA_INDEX'].astype(str)
DDECU_1 = DDECU_1.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_1=DDECU_1.drop_duplicates(['KEY'])
DDECU_1.rename(columns = lambda x: "ECU1_" + x, inplace = True)
DDECU_1.rename(columns = {'ECU1_KEY' : 'KEY'},inplace=True)

DDECU_2 = DDECU.loc[DDECU['DEVICE_ID'] == 2,:]
DDECU_2['KEY']=DDECU_2['SHIP_ID'] + "_" + DDECU_2['SECTION'].astype(str) + "_" + DDECU_2['OP_INDEX'].astype(str) + "_" + DDECU_2['DATA_INDEX'].astype(str)
DDECU_2 = DDECU_2.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_2=DDECU_2.drop_duplicates(['KEY'])
DDECU_2.rename(columns = lambda x: "ECU2_" + x, inplace = True)
DDECU_2.rename(columns = {'ECU2_KEY' : 'KEY'},inplace=True)

DDECU_3 = DDECU.loc[DDECU['DEVICE_ID'] == 3,:]
DDECU_3['KEY']=DDECU_3['SHIP_ID'] + "_" + DDECU_3['SECTION'].astype(str) + "_" + DDECU_3['OP_INDEX'].astype(str) + "_" + DDECU_3['DATA_INDEX'].astype(str)
DDECU_3 = DDECU_3.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_3=DDECU_3.drop_duplicates(['KEY'])
DDECU_3.rename(columns = lambda x: "ECU3_" + x, inplace = True)
DDECU_3.rename(columns = {'ECU3_KEY' : 'KEY'},inplace=True)

DDECU_4 = DDECU.loc[DDECU['DEVICE_ID'] == 4,:]
DDECU_4['KEY']=DDECU_4['SHIP_ID'] + "_" + DDECU_4['SECTION'].astype(str) + "_" + DDECU_4['OP_INDEX'].astype(str) + "_" + DDECU_4['DATA_INDEX'].astype(str)
DDECU_4 = DDECU_4.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_4=DDECU_4.drop_duplicates(['KEY'])
DDECU_4.rename(columns = lambda x: "ECU4_" + x, inplace = True)
DDECU_4.rename(columns = {'ECU4_KEY' : 'KEY'},inplace=True)

DDECU_5 = DDECU.loc[DDECU['DEVICE_ID'] == 5,:]
DDECU_5['KEY']=DDECU_5['SHIP_ID'] + "_" + DDECU_5['SECTION'].astype(str) + "_" + DDECU_5['OP_INDEX'].astype(str) + "_" + DDECU_5['DATA_INDEX'].astype(str)
DDECU_5 = DDECU_5.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_5=DDECU_5.drop_duplicates(['KEY'])
DDECU_5.rename(columns = lambda x: "ECU5_" + x, inplace = True)
DDECU_5.rename(columns = {'ECU5_KEY' : 'KEY'},inplace=True)

DDECU_6 = DDECU.loc[DDECU['DEVICE_ID'] == 6,:]
DDECU_6['KEY']=DDECU_6['SHIP_ID'] + "_" + DDECU_6['SECTION'].astype(str) + "_" + DDECU_6['OP_INDEX'].astype(str) + "_" + DDECU_6['DATA_INDEX'].astype(str)
DDECU_6 = DDECU_6.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_6=DDECU_6.drop_duplicates(['KEY'])
DDECU_6.rename(columns = lambda x: "ECU6_" + x, inplace = True)
DDECU_6.rename(columns = {'ECU6_KEY' : 'KEY'},inplace=True)

DDECU_7 = DDECU.loc[DDECU['DEVICE_ID'] == 7,:]
DDECU_7['KEY']=DDECU_7['SHIP_ID'] + "_" + DDECU_7['SECTION'].astype(str) + "_" + DDECU_7['OP_INDEX'].astype(str) + "_" + DDECU_7['DATA_INDEX'].astype(str)
DDECU_7 = DDECU_7.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_7=DDECU_7.drop_duplicates(['KEY'])
DDECU_7.rename(columns = lambda x: "ECU7_" + x, inplace = True)
DDECU_7.rename(columns = {'ECU7_KEY' : 'KEY'},inplace=True)

DDECU_8 = DDECU.loc[DDECU['DEVICE_ID'] == 8,:]
DDECU_8['KEY']=DDECU_8['SHIP_ID'] + "_" + DDECU_8['SECTION'].astype(str) + "_" + DDECU_8['OP_INDEX'].astype(str) + "_" + DDECU_8['DATA_INDEX'].astype(str)
DDECU_8 = DDECU_8.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_8=DDECU_8.drop_duplicates(['KEY'])
DDECU_8.rename(columns = lambda x: "ECU8_" + x, inplace = True)
DDECU_8.rename(columns = {'ECU8_KEY' : 'KEY'},inplace=True)

DDECU_9 = DDECU.loc[DDECU['DEVICE_ID'] == 9,:]
DDECU_9['KEY']=DDECU_9['SHIP_ID'] + "_" + DDECU_9['SECTION'].astype(str) + "_" + DDECU_9['OP_INDEX'].astype(str) + "_" + DDECU_9['DATA_INDEX'].astype(str)
DDECU_9 = DDECU_9.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDECU_9=DDECU_9.drop_duplicates(['KEY'])
DDECU_9.rename(columns = lambda x: "ECU9_" + x, inplace = True)
DDECU_9.rename(columns = {'ECU9_KEY' : 'KEY'},inplace=True)


DDANU_1 = DDANU.loc[DDANU['DEVICE_ID'] == 1,:]
DDANU_1['KEY']=DDANU_1['SHIP_ID'] + "_" + DDANU_1['SECTION'].astype(str) + "_" + DDANU_1['OP_INDEX'].astype(str) + "_" + DDANU_1['DATA_INDEX'].astype(str)
DDANU_1 = DDANU_1.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_1=DDANU_1.drop_duplicates(['KEY'])
DDANU_1.rename(columns = lambda x: "ANU1_" + x, inplace = True)
DDANU_1.rename(columns = {'ANU1_KEY' : 'KEY'},inplace=True)

DDANU_2 = DDANU.loc[DDANU['DEVICE_ID'] == 2,:]
DDANU_2['KEY']=DDANU_2['SHIP_ID'] + "_" + DDANU_2['SECTION'].astype(str) + "_" + DDANU_2['OP_INDEX'].astype(str) + "_" + DDANU_2['DATA_INDEX'].astype(str)
DDANU_2 = DDANU_2.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_2=DDANU_2.drop_duplicates(['KEY'])
DDANU_2.rename(columns = lambda x: "ANU2_" + x, inplace = True)
DDANU_2.rename(columns = {'ANU2_KEY' : 'KEY'},inplace=True)

DDANU_3 = DDANU.loc[DDANU['DEVICE_ID'] == 3,:]
DDANU_3['KEY']=DDANU_3['SHIP_ID'] + "_" + DDANU_3['SECTION'].astype(str) + "_" + DDANU_3['OP_INDEX'].astype(str) + "_" + DDANU_3['DATA_INDEX'].astype(str)
DDANU_3 = DDANU_3.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_3=DDANU_3.drop_duplicates(['KEY'])
DDANU_3.rename(columns = lambda x: "ANU3_" + x, inplace = True)
DDANU_3.rename(columns = {'ANU3_KEY' : 'KEY'},inplace=True)

DDANU_4 = DDANU.loc[DDANU['DEVICE_ID'] == 4,:]
DDANU_4['KEY']=DDANU_4['SHIP_ID'] + "_" + DDANU_4['SECTION'].astype(str) + "_" + DDANU_4['OP_INDEX'].astype(str) + "_" + DDANU_4['DATA_INDEX'].astype(str)
DDANU_4 = DDANU_4.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_4=DDANU_4.drop_duplicates(['KEY'])
DDANU_4.rename(columns = lambda x: "ANU4_" + x, inplace = True)
DDANU_4.rename(columns = {'ANU4_KEY' : 'KEY'},inplace=True)

DDANU_5 = DDANU.loc[DDANU['DEVICE_ID'] == 5,:]
DDANU_5['KEY']=DDANU_5['SHIP_ID'] + "_" + DDANU_5['SECTION'].astype(str) + "_" + DDANU_5['OP_INDEX'].astype(str) + "_" + DDANU_5['DATA_INDEX'].astype(str)
DDANU_5 = DDANU_5.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_5=DDANU_5.drop_duplicates(['KEY'])
DDANU_5.rename(columns = lambda x: "ANU5_" + x, inplace = True)
DDANU_5.rename(columns = {'ANU5_KEY' : 'KEY'},inplace=True)

DDANU_6 = DDANU.loc[DDANU['DEVICE_ID'] == 6,:]
DDANU_6['KEY']=DDANU_6['SHIP_ID'] + "_" + DDANU_6['SECTION'].astype(str) + "_" + DDANU_6['OP_INDEX'].astype(str) + "_" + DDANU_6['DATA_INDEX'].astype(str)
DDANU_6 = DDANU_6.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_6=DDANU_6.drop_duplicates(['KEY'])
DDANU_6.rename(columns = lambda x: "ANU6_" + x, inplace = True)
DDANU_6.rename(columns = {'ANU6_KEY' : 'KEY'},inplace=True)

DDANU_7 = DDANU.loc[DDANU['DEVICE_ID'] == 7,:]
DDANU_7['KEY']=DDANU_7['SHIP_ID'] + "_" + DDANU_7['SECTION'].astype(str) + "_" + DDANU_7['OP_INDEX'].astype(str) + "_" + DDANU_7['DATA_INDEX'].astype(str)
DDANU_7 = DDANU_7.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_7=DDANU_7.drop_duplicates(['KEY'])
DDANU_7.rename(columns = lambda x: "ANU7_" + x, inplace = True)
DDANU_7.rename(columns = {'ANU7_KEY' : 'KEY'},inplace=True)

DDANU_8 = DDANU.loc[DDANU['DEVICE_ID'] == 8,:]
DDANU_8['KEY']=DDANU_8['SHIP_ID'] + "_" + DDANU_8['SECTION'].astype(str) + "_" + DDANU_8['OP_INDEX'].astype(str) + "_" + DDANU_8['DATA_INDEX'].astype(str)
DDANU_8 = DDANU_8.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDANU_8=DDANU_8.drop_duplicates(['KEY'])
DDANU_8.rename(columns = lambda x: "ANU8_" + x, inplace = True)
DDANU_8.rename(columns = {'ANU8_KEY' : 'KEY'},inplace=True)

DDPMU_1 = DDPMU.loc[DDPMU['DEVICE_ID'] == 1,:]
DDPMU_1['KEY']=DDPMU_1['SHIP_ID'] + "_" + DDPMU_1['SECTION'].astype(str) + "_" + DDPMU_1['OP_INDEX'].astype(str) + "_" + DDPMU_1['DATA_INDEX'].astype(str)
DDPMU_1 = DDPMU_1.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_1=DDPMU_1.drop_duplicates(['KEY'])
DDPMU_1.rename(columns = lambda x: "PMU1_" + x, inplace = True)
DDPMU_1.rename(columns = {'PMU1_KEY' : 'KEY'},inplace=True)

DDPMU_2 = DDPMU.loc[DDPMU['DEVICE_ID'] == 2,:]
DDPMU_2['KEY']=DDPMU_2['SHIP_ID'] + "_" + DDPMU_2['SECTION'].astype(str) + "_" + DDPMU_2['OP_INDEX'].astype(str) + "_" + DDPMU_2['DATA_INDEX'].astype(str)
DDPMU_2 = DDPMU_2.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_2=DDPMU_2.drop_duplicates(['KEY'])
DDPMU_2.rename(columns = lambda x: "PMU2_" + x, inplace = True)
DDPMU_2.rename(columns = {'PMU2_KEY' : 'KEY'},inplace=True)

DDPMU_3 = DDPMU.loc[DDPMU['DEVICE_ID'] == 3,:]
DDPMU_3['KEY']=DDPMU_3['SHIP_ID'] + "_" + DDPMU_3['SECTION'].astype(str) + "_" + DDPMU_3['OP_INDEX'].astype(str) + "_" + DDPMU_3['DATA_INDEX'].astype(str)
DDPMU_3 = DDPMU_3.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_3=DDPMU_3.drop_duplicates(['KEY'])
DDPMU_3.rename(columns = lambda x: "PMU3_" + x, inplace = True)
DDPMU_3.rename(columns = {'PMU3_KEY' : 'KEY'},inplace=True)

DDPMU_4 = DDPMU.loc[DDPMU['DEVICE_ID'] == 4,:]
DDPMU_4['KEY']=DDPMU_4['SHIP_ID'] + "_" + DDPMU_4['SECTION'].astype(str) + "_" + DDPMU_4['OP_INDEX'].astype(str) + "_" + DDPMU_4['DATA_INDEX'].astype(str)
DDPMU_4 = DDPMU_4.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_4=DDPMU_4.drop_duplicates(['KEY'])
DDPMU_4.rename(columns = lambda x: "PMU4_" + x, inplace = True)
DDPMU_4.rename(columns = {'PMU4_KEY' : 'KEY'},inplace=True)

DDPMU_5 = DDPMU.loc[DDPMU['DEVICE_ID'] == 5,:]
DDPMU_5['KEY']=DDPMU_5['SHIP_ID'] + "_" + DDPMU_5['SECTION'].astype(str) + "_" + DDPMU_5['OP_INDEX'].astype(str) + "_" + DDPMU_5['DATA_INDEX'].astype(str)
DDPMU_5 = DDPMU_5.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_5=DDPMU_5.drop_duplicates(['KEY'])
DDPMU_5.rename(columns = lambda x: "PMU5_" + x, inplace = True)
DDPMU_5.rename(columns = {'PMU5_KEY' : 'KEY'},inplace=True)

DDPMU_6 = DDPMU.loc[DDPMU['DEVICE_ID'] == 6,:]
DDPMU_6['KEY']=DDPMU_6['SHIP_ID'] + "_" + DDPMU_6['SECTION'].astype(str) + "_" + DDPMU_6['OP_INDEX'].astype(str) + "_" + DDPMU_6['DATA_INDEX'].astype(str)
DDPMU_6 = DDPMU_6.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_6=DDPMU_6.drop_duplicates(['KEY'])
DDPMU_6.rename(columns = lambda x: "PMU6_" + x, inplace = True)
DDPMU_6.rename(columns = {'PMU6_KEY' : 'KEY'},inplace=True)

DDPMU_7 = DDPMU.loc[DDPMU['DEVICE_ID'] == 7,:]
DDPMU_7['KEY']=DDPMU_7['SHIP_ID'] + "_" + DDPMU_7['SECTION'].astype(str) + "_" + DDPMU_7['OP_INDEX'].astype(str) + "_" + DDPMU_7['DATA_INDEX'].astype(str)
DDPMU_7 = DDPMU_7.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_7=DDPMU_7.drop_duplicates(['KEY'])
DDPMU_7.rename(columns = lambda x: "PMU7_" + x, inplace = True)
DDPMU_7.rename(columns = {'PMU7_KEY' : 'KEY'},inplace=True)

DDPMU_8 = DDPMU.loc[DDPMU['DEVICE_ID'] == 8,:]
DDPMU_8['KEY']=DDPMU_8['SHIP_ID'] + "_" + DDPMU_8['SECTION'].astype(str) + "_" + DDPMU_8['OP_INDEX'].astype(str) + "_" + DDPMU_8['DATA_INDEX'].astype(str)
DDPMU_8 = DDPMU_8.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_8=DDPMU_8.drop_duplicates(['KEY'])
DDPMU_8.rename(columns = lambda x: "PMU8_" + x, inplace = True)
DDPMU_8.rename(columns = {'PMU8_KEY' : 'KEY'},inplace=True)

DDPMU_9 = DDPMU.loc[DDPMU['DEVICE_ID'] == 9,:]
DDPMU_9['KEY']=DDPMU_9['SHIP_ID'] + "_" + DDPMU_9['SECTION'].astype(str) + "_" + DDPMU_9['OP_INDEX'].astype(str) + "_" + DDPMU_9['DATA_INDEX'].astype(str)
DDPMU_9 = DDPMU_9.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_9=DDPMU_9.drop_duplicates(['KEY'])
DDPMU_9.rename(columns = lambda x: "PMU9_" + x, inplace = True)
DDPMU_9.rename(columns = {'PMU9_KEY' : 'KEY'},inplace=True)

DDPMU_10 = DDPMU.loc[DDPMU['DEVICE_ID'] == 10,:]
DDPMU_10['KEY']=DDPMU_10['SHIP_ID'] + "_" + DDPMU_10['SECTION'].astype(str) + "_" + DDPMU_10['OP_INDEX'].astype(str) + "_" + DDPMU_10['DATA_INDEX'].astype(str)
DDPMU_10 = DDPMU_10.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDPMU_10=DDPMU_10.drop_duplicates(['KEY'])
DDPMU_10.rename(columns = lambda x: "PMU10_" + x, inplace = True)
DDPMU_10.rename(columns = {'PMU10_KEY' : 'KEY'},inplace=True)

DDTSU_1 = DDTSU.loc[DDTSU['DEVICE_ID'] == 1,:]
DDTSU_1['KEY']=DDTSU_1['SHIP_ID'] + "_" + DDTSU_1['SECTION'].astype(str) + "_" + DDTSU_1['OP_INDEX'].astype(str) + "_" + DDTSU_1['DATA_INDEX'].astype(str)
DDTSU_1 = DDTSU_1.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDTSU_1=DDTSU_1.drop_duplicates(['KEY'])
DDTSU_1.rename(columns = lambda x: "TSU1_" + x, inplace = True)
DDTSU_1.rename(columns = {'TSU1_KEY' : 'KEY'},inplace=True)

DDTSU_2 = DDTSU.loc[DDTSU['DEVICE_ID'] == 2,:]
DDTSU_2['KEY']=DDTSU_2['SHIP_ID'] + "_" + DDTSU_2['SECTION'].astype(str) + "_" + DDTSU_2['OP_INDEX'].astype(str) + "_" + DDTSU_2['DATA_INDEX'].astype(str)
DDTSU_2 = DDTSU_2.drop(columns = ['SHIP_ID', 'D_INDEX', 'DEVICE_ID', 'SECTION', 'DATA_INDEX', 'OP_INDEX', 'DEVICETYPE'])
DDTSU_2=DDTSU_2.drop_duplicates(['KEY'])
DDTSU_2.rename(columns = lambda x: "TSU2_" + x, inplace = True)
DDTSU_2.rename(columns = {'TSU2_KEY' : 'KEY'},inplace=True)

DATA['KEY']=DATA['SHIP_ID'] + "_" + DATA['SECTION'].astype(str) + "_" + DATA['OP_INDEX'].astype(str) + "_" + DATA['DATA_INDEX'].astype(str)
DATA1=pd.merge(DATA,DDECU_1,how='left', on = 'KEY')
DATA2=pd.merge(DATA,DDECU_2,how='left', on = 'KEY')
DATA3=pd.merge(DATA,DDECU_3,how='left', on = 'KEY')
DATA4=pd.merge(DATA,DDECU_4,how='left', on = 'KEY')
DATA5=pd.merge(DATA,DDECU_5,how='left', on = 'KEY')
DATA6=pd.merge(DATA,DDECU_6,how='left', on = 'KEY')
DATA7=pd.merge(DATA,DDECU_7,how='left', on = 'KEY')
DATA8=pd.merge(DATA,DDECU_8,how='left', on = 'KEY')
DATA9=pd.merge(DATA,DDECU_9,how='left', on = 'KEY')

DATA11=pd.merge(DATA,DDANU_1,how='left', on = 'KEY')
DATA12=pd.merge(DATA,DDANU_2,how='left', on = 'KEY')
DATA13=pd.merge(DATA,DDANU_3,how='left', on = 'KEY')
DATA14=pd.merge(DATA,DDANU_4,how='left', on = 'KEY')
DATA15=pd.merge(DATA,DDANU_5,how='left', on = 'KEY')
DATA16=pd.merge(DATA,DDANU_6,how='left', on = 'KEY')
DATA17=pd.merge(DATA,DDANU_7,how='left', on = 'KEY')
DATA18=pd.merge(DATA,DDANU_8,how='left', on = 'KEY')


DATA21=pd.merge(DATA,DDPMU_1,how='left', on = 'KEY')
DATA22=pd.merge(DATA,DDPMU_2,how='left', on = 'KEY')
DATA23=pd.merge(DATA,DDPMU_3,how='left', on = 'KEY')
DATA24=pd.merge(DATA,DDPMU_4,how='left', on = 'KEY')
DATA25=pd.merge(DATA,DDPMU_5,how='left', on = 'KEY')
DATA26=pd.merge(DATA,DDPMU_6,how='left', on = 'KEY')
DATA27=pd.merge(DATA,DDPMU_7,how='left', on = 'KEY')
DATA28=pd.merge(DATA,DDPMU_8,how='left', on = 'KEY')
DATA29=pd.merge(DATA,DDPMU_9,how='left', on = 'KEY')
DATA210=pd.merge(DATA,DDPMU_10,how='left', on = 'KEY')

DATA31=pd.merge(DATA,DDTSU_1,how='left', on = 'KEY')
DATA32=pd.merge(DATA,DDTSU_2,how='left', on = 'KEY')


DATA1 = DATA1.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA2 = DATA2.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA3 = DATA3.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA4 = DATA4.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA5 = DATA5.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA6 = DATA6.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA7 = DATA7.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA8 = DATA8.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA9 = DATA9.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])

DATA11 = DATA11.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA12 = DATA12.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA13 = DATA13.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA14 = DATA14.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA15 = DATA15.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA16 = DATA16.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA17 = DATA17.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA18 = DATA18.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])

DATA21 = DATA21.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA22 = DATA22.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA23 = DATA23.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA24 = DATA24.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA25 = DATA25.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA26 = DATA26.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA27 = DATA27.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA28 = DATA28.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA29 = DATA29.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA210 = DATA210.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])

DATA31 = DATA31.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])
DATA32 = DATA32.drop(columns = ['OP_INDEX',	'DATA_INDEX',	'DATA_TIME',	'CSU',	'STS',	'FTS',	'FMU',	'TRO',	'ANU',	'RATE',	'CURRENT',	'VOLTAGE'	,'TRO_COUNT',	'SHIP_ID',	'SECTION',	'KEY'])

DATA_DATA_DEVICE=pd.concat([DATA,
           DATA1,
           DATA2,
           DATA3,
           DATA4,
           DATA5,
           DATA6,
           DATA7,
           DATA8,
           DATA9,
           DATA11,
           DATA12,
           DATA13,
           DATA14,
           DATA15,
           DATA16,
           DATA17,
           DATA18,
           DATA21,
           DATA22,
           DATA23,
           DATA24,
           DATA25,
           DATA26,
           DATA27,
           DATA28,
           DATA29,
           DATA210,
           DATA31,
           DATA32],axis = 1)

temp = list(DATA_DATA_DEVICE.columns)
DATA['VOLTAGE'] = DATA_DATA_DEVICE[list(set([i for i in temp if "VOLTAGE" in i])-set(DATA.columns))].mean(1)
DATA['VOLTAGE']=DATA['VOLTAGE'].fillna(0)
DATA['CURRENT'] = DATA_DATA_DEVICE[list(set([i for i in temp if "CURRENT" in i])-set(DATA.columns))].sum(1)
DATA['TRO'] = DATA_DATA_DEVICE[list(set([i for i in temp if "BP" in i])-set(DATA.columns))].mean(1)
DATA['TRO']=DATA['TRO'].fillna(0)
DATA['ANU'] = DATA_DATA_DEVICE[list(set([i for i in temp if "AMOUNT" in i])-set(DATA.columns))].mean(1)
DATA['ANU']=DATA['ANU'].fillna(0)
DATA['PMU'] = DATA_DATA_DEVICE[list(set([i for i in temp if "PSUM" in i])-set(DATA.columns))].mean(1)
DATA['PMU']=DATA['PMU'].fillna(0)


##################################################################################

############## THIS IS LONG ######################################################

##################################################################################


origin_col_DATA_DEVICE = DATA_DEVICE.columns
DATA_DEVICE['KEY'] = DATA_DEVICE['SHIP_ID'] + "_" + DATA_DEVICE['SECTION'].astype(str) + "_" + DATA_DEVICE['DEVICE_ID'].astype(str) + "_" +DATA_DEVICE['D_INDEX'].astype(str)
ECUDD=DATA_DEVICE[DATA_DEVICE['DEVICETYPE'] == 1]
ANUDD=DATA_DEVICE[DATA_DEVICE['DEVICETYPE'] == 2]
TSUDD=DATA_DEVICE[DATA_DEVICE['DEVICETYPE'] == 3]
PMUDD=DATA_DEVICE[DATA_DEVICE['DEVICETYPE'] == 4]
ANU['KEY'] = ANU['SHIP_ID'] + "_" + ANU['SECTION'].astype(str) + "_" + ANU['DEVICE_ID'].astype(str) + "_" +ANU['D_INDEX'].astype(str)
TSU['KEY'] = TSU['SHIP_ID'] + "_" + TSU['SECTION'].astype(str) + "_" + TSU['DEVICE_ID'].astype(str) + "_" +TSU['D_INDEX'].astype(str)
PMU['KEY'] = PMU['SHIP_ID'] + "_" + PMU['SECTION'].astype(str) + "_" + PMU['DEVICE_ID'].astype(str) + "_" +PMU['D_INDEX'].astype(str)
ECU['KEY'] = ECU['SHIP_ID'] + "_" + ECU['SECTION'].astype(str) + "_" + ECU['DEVICE_ID'].astype(str) + "_" +ECU['D_INDEX'].astype(str)

mer_DATA_DEVICE_ECU=pd.merge(ECU,ECUDD, how = 'left' , on = 'KEY')
mer_DATA_DEVICE_ECU[mer_DATA_DEVICE_ECU['SHIP_ID_y'].isna()]
mer_DATA_DEVICE_ANU=pd.merge(ANU,ANUDD, how = 'left' , on = 'KEY')
mer_DATA_DEVICE_ANU[mer_DATA_DEVICE_ANU['SHIP_ID_y'].isna()]
mer_DATA_DEVICE_TSU=pd.merge(TSU,TSUDD, how = 'left' , on = 'KEY')
mer_DATA_DEVICE_TSU[mer_DATA_DEVICE_TSU['SHIP_ID_y'].isna()]
mer_DATA_DEVICE_PMU=pd.merge(PMU,PMUDD, how = 'left' , on = 'KEY')
mer_DATA_DEVICE_PMU[mer_DATA_DEVICE_PMU['SHIP_ID_y'].isna()]

ECU_DROP_KEY = mer_DATA_DEVICE_ECU[mer_DATA_DEVICE_ECU['SHIP_ID_y'].isna()]['KEY']
ANU_DROP_KEY = mer_DATA_DEVICE_ANU[mer_DATA_DEVICE_ANU['SHIP_ID_y'].isna()]['KEY']
TSU_DROP_KEY = mer_DATA_DEVICE_TSU[mer_DATA_DEVICE_TSU['SHIP_ID_y'].isna()]['KEY']
PMU_DROP_KEY = mer_DATA_DEVICE_PMU[mer_DATA_DEVICE_PMU['SHIP_ID_y'].isna()]['KEY']
ECU_DROP_KEY=ECU_DROP_KEY.to_list()
ANU_DROP_KEY=ANU_DROP_KEY.to_list()
TSU_DROP_KEY=TSU_DROP_KEY.to_list()
PMU_DROP_KEY=PMU_DROP_KEY.to_list()

ECU.index = ECU['KEY']
ANU.index = ANU['KEY']
TSU.index = TSU['KEY']
PMU.index = PMU['KEY']

ECU = ECU.drop(ECU_DROP_KEY)
ECU.drop(columns = ['KEY'], inplace  = True)
ECU=ECU.reset_index()
ECU = ECU.drop(columns = ['KEY'])

ANU = ANU.drop(ANU_DROP_KEY)
ANU.drop(columns = ['KEY'], inplace  = True)
ANU=ANU.reset_index()
ANU = ANU.drop(columns = ['KEY'])

TSU = TSU.drop(TSU_DROP_KEY)
TSU.drop(columns = ['KEY'], inplace  = True)
TSU=TSU.reset_index()
TSU = TSU.drop(columns = ['KEY'])

PMU = PMU.drop(PMU_DROP_KEY)
PMU.drop(columns = ['KEY'], inplace  = True)
PMU=PMU.reset_index()
PMU = PMU.drop(columns = ['KEY'])

DATA['DUP'] = DATA['SHIP_ID'] + "_" + DATA["SECTION"].astype(str) + "_" + DATA["OP_INDEX"].astype(str)+ DATA["DATA_TIME"]
data_time_key = DATA['DUP']

DATA = DATA.drop_duplicates(subset = ['OP_INDEX', 'DATA_TIME', 'CSU', 'STS', 'FTS','FMU','TRO','ANU', 'RATE','CURRENT','VOLTAGE','TRO_COUNT','SHIP_ID','SECTION','DUP'])
DATA=DATA.reset_index().drop(columns = ['index','DUP'])

ECUDD_ECU = pd.merge(ECUDD,ECU,how = "left", on = ['SHIP_ID', 'SECTION','D_INDEX','DEVICE_ID'])
ECU_TIME = pd.merge(ECUDD_ECU,DATA[['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX','DATA_TIME']],how = "left", on = ['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX'])

ANUDD_ANU = pd.merge(ANUDD,ANU,how = "left", on = ['SHIP_ID', 'SECTION','D_INDEX','DEVICE_ID'])
ANU_TIME = pd.merge(ANUDD_ANU,DATA[['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX','DATA_TIME']],how = "left", on = ['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX'])

TSUDD_TSU = pd.merge(TSUDD,TSU,how = "left", on = ['SHIP_ID', 'SECTION','D_INDEX','DEVICE_ID'])
TSU_TIME = pd.merge(TSUDD_TSU,DATA[['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX','DATA_TIME']],how = "left", on = ['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX'])

PMUDD_PMU = pd.merge(PMUDD,PMU,how = "left", on = ['SHIP_ID', 'SECTION','D_INDEX','DEVICE_ID'])
PMU_TIME = pd.merge(PMUDD_PMU,DATA[['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX','DATA_TIME']],how = "left", on = ['SHIP_ID','SECTION','OP_INDEX','DATA_INDEX'])

ECU_TIME = ECU_TIME[ECU_TIME['DATA_TIME'].isna() == False]
ANU_TIME  = ANU_TIME[ANU_TIME['DATA_TIME'].isna() == False]
TSU_TIME  = TSU_TIME[TSU_TIME['DATA_TIME'].isna() == False]
PMU_TIME  = PMU_TIME[PMU_TIME['DATA_TIME'].isna() == False]

ECU_TIME["DUP"] = ECU_TIME['SHIP_ID'] + "_" + ECU_TIME['SECTION'].astype(str) + "_" + ECU_TIME['OP_INDEX'].astype(str)  + "_" + ECU_TIME['DEVICE_ID'].astype(str) + ECU_TIME['DATA_TIME']

ANU_TIME["DUP"] = ANU_TIME['SHIP_ID'] + "_" + ANU_TIME['SECTION'].astype(str) + "_" +  ANU_TIME['OP_INDEX'].astype(str)  + "_"  + ANU_TIME['DEVICE_ID'].astype(str) + ANU_TIME['DATA_TIME']

TSU_TIME["DUP"] = TSU_TIME['SHIP_ID'] + "_" + TSU_TIME['SECTION'].astype(str) + "_" + TSU_TIME['OP_INDEX'].astype(str)  + "_"  +TSU_TIME['DEVICE_ID'].astype(str) + TSU_TIME['DATA_TIME']

PMU_TIME["DUP"] = PMU_TIME['SHIP_ID'] + "_" + PMU_TIME['SECTION'].astype(str) + "_" + PMU_TIME['OP_INDEX'].astype(str)  + "_" + PMU_TIME['DEVICE_ID'].astype(str) + PMU_TIME['DATA_TIME']

ECU = ECU_TIME.reset_index().drop(columns = ['index'])
ANU = ANU_TIME.reset_index().drop(columns = ['index'])
TSU = TSU_TIME.reset_index().drop(columns = ['index'])
PMU = PMU_TIME.reset_index().drop(columns = ['index'])

ECU_COL=list(set(ECU_COL) - set(['SYSTEM']))
ANU_COL=list(set(ANU_COL) - set(['SYSTEM']))
TSU_COL=list(set(TSU_COL) - set(['SYSTEM']))
PMU_COL=list(set(PMU_COL) - set(['SYSTEM']))
ECU = ECU[ECU_COL]
ANU = ANU[ANU_COL]
TSU = TSU[TSU_COL]
PMU = PMU[PMU_COL]


DATA_DEVICE.drop(columns = ['KEY'], inplace = True)

DATA_DEVICE=DATA_DEVICE.reset_index()
DATA=DATA.reset_index()
ANU=ANU.reset_index()
TSU=TSU.reset_index()
PMU=PMU.reset_index()
ECU=ECU.reset_index()
OPTIME=OPTIME.reset_index()
EVENT=EVENT.reset_index()
OPTIME_EVENT=OPTIME_EVENT.reset_index()

DATA.drop(columns = ["TRO_COUNT"],inplace = True)
OPTIME['START_TIME'] = OPTIME['START_TIME'].astype("datetime64")
OPTIME['END_TIME'] = OPTIME['END_TIME'].astype("datetime64")
EVENT['OCCUR_TIME'] = EVENT['OCCUR_TIME'].astype("datetime64")

OPTIME['NORMAL'] = 0
OPTIME['WARN'] = 0
OPTIME['FATAL'] = 0

for i in range(len(OPTIME)) :
    TEMP_OPTIME = OPTIME.iloc[i]
    TEMP_START = TEMP_OPTIME['START_TIME']
    TEMP_END = TEMP_OPTIME['END_TIME']
    TEMP_SHIP_ID = TEMP_OPTIME['SHIP_ID']
    TEMP_SECTION = TEMP_OPTIME['SECTION']
    TEMP_EVENT = EVENT[(EVENT['SHIP_ID'] == TEMP_SHIP_ID) & (EVENT['SECTION'] == TEMP_SECTION) & (EVENT['OCCUR_TIME']>=TEMP_START) & (EVENT['OCCUR_TIME']<=TEMP_END)]
    OPTIME['NORMAL'][i]= list(TEMP_EVENT['LOG_LEVEL'] == 0).count(True)
    OPTIME['WARN'][i]= list(TEMP_EVENT['LOG_LEVEL'] == 1).count(True)
    OPTIME['FATAL'][i]= list(TEMP_EVENT['LOG_LEVEL'] == 2).count(True)

OPTIME.drop(columns = ['SYSTEM','RUNNING_TIME', 'VOLUME','LATITUDE', 'LONGITUDE', 'ALARM_COUNT', 'FAULT_COUNT', 'FAULT_CODE','VOYAGE','TOTAL_POWER', 'FILE_INDEX', 'MODE','REGION_ID',
       'STATE'],inplace = True)
OPTIME.drop(columns = ['index'], inplace = True)
OPTIME_DATA=pd.merge(DATA,OPTIME,how = "left", on = ["SHIP_ID","SECTION", "OP_INDEX"])
OPTIME_DATA=OPTIME_DATA.groupby(list(OPTIME.columns)).mean().reset_index()
OPTIME_DATA.drop(columns = ['DATA_INDEX', 'RATE','SYSTEM'],inplace = True)
OPTIME_DATA.drop(columns = ['TRO_AVG','ANU_AMOUNT'],inplace = True)
OPTIME_DATA["KEY"] = OPTIME_DATA['SHIP_ID'] + "_" + OPTIME_DATA['SECTION'].astype(str)
KEY_LIST=list(OPTIME_DATA["KEY"].unique())
OPTIME_DATA = OPTIME_DATA[["SHIP_ID","SECTION","START_TIME","END_TIME", "OP_INDEX","OP_TYPE","LINE","CSU",'STS','FMU','TRO','ANU','CURRENT','VOLTAGE','PMU','NORMAL','WARN','FATAL']]
OPTIME_DATA['NORMAL_PERCENT'] = OPTIME_DATA['NORMAL'] / (OPTIME_DATA['NORMAL'] + OPTIME_DATA['WARN'] + OPTIME_DATA['FATAL'])
OPTIME_DATA['WARN_PERCENT'] = OPTIME_DATA['WARN'] / (OPTIME_DATA['NORMAL'] + OPTIME_DATA['WARN'] + OPTIME_DATA['FATAL'])
OPTIME_DATA['FATAL_PERCENT'] = OPTIME_DATA['FATAL'] / (OPTIME_DATA['NORMAL'] + OPTIME_DATA['WARN'] + OPTIME_DATA['FATAL'])
OPTIME_DATA.drop(columns = ["NORMAL","WARN","FATAL"], inplace = True)

OPTIME_DATA.loc[OPTIME_DATA["FATAL_PERCENT"] == 0,"decision"]= "GOOD"
OPTIME_DATA.loc[OPTIME_DATA["FATAL_PERCENT"] != 0,"decision"]= "FATAL"

print('예측 라벨링 중...')

PREDICT_1 = OPTIME_DATA.iloc[:len(OPTIME_DATA)-1,:]
PREDICT_1["PREDICT"] = OPTIME_DATA.iloc[1:].reset_index()['decision']

PREDICT_2 = OPTIME_DATA.iloc[:len(OPTIME_DATA)-2,:]
PREDICT_2["PREDICT"] = OPTIME_DATA.iloc[2:].reset_index()['decision']

PREDICT_3 = OPTIME_DATA.iloc[:len(OPTIME_DATA)-3,:]
PREDICT_3["PREDICT"] = OPTIME_DATA.iloc[3:].reset_index()['decision']

PREDICT_1['ORIGIN'] = 0
PREDICT_1['PREDICT_1'] = 0
PREDICT_1['PREDICT_2'] = 0
PREDICT_1['PREDICT_3'] = 0

for i in list(PREDICT_1[PREDICT_1['PREDICT'] == 'FATAL'].index) :
    PREDICT_1.iloc[i,-3] = ('FATAL_1')

for i in list(PREDICT_2[PREDICT_2['PREDICT'] == 'FATAL'].index) :
    PREDICT_1.iloc[i,-2] = ('FATAL_2')

for i in list(PREDICT_3[PREDICT_3['PREDICT'] == 'FATAL'].index) :
    PREDICT_1.iloc[i,-1] = ('FATAL_3')

for i in list(PREDICT_1[PREDICT_1['decision'] == 'FATAL'].index) :
    PREDICT_1.iloc[i,-4] = ('FATAL')


for i in range(len(PREDICT_1)) :
    if PREDICT_1.iloc[i,-1] == 0 :
        PREDICT_1.iloc[i,-1] = 'NORMAL'
    if PREDICT_1.iloc[i,-2] == 0 :
        PREDICT_1.iloc[i,-2] = 'NORMAL'
    if PREDICT_1.iloc[i,-3] == 0 :
        PREDICT_1.iloc[i,-3] = 'NORMAL'
    if PREDICT_1.iloc[i,-4] == 0 :
        PREDICT_1.iloc[i,-4] = 'NORMAL'


PREDICT_1.drop(columns = ['PREDICT'], inplace = True)

end_time = time.time()
print("걸린시간 : ", end_time - start_time)


print("어디에 저장할까요?")
print("파일 경로")
load = input()
print("파일 이름")
name = input()
PREDICT_1.to_csv(load +"/" +  name + ".csv")
# Out:
# 주의사항
# 폴더 안의 파일이름이 제시되는 질문의 파일 이름과 모두 같고, 확장자는 csv 파일이어야 합니다.
# colab 환경이십니까? : yes/no
# yes
# 코랩 로딩중...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 호선의 ID를 입력하세요
# T140128-00703
# 몇번째 SECTION입니까?
# 0
# 폴더 경로를 입력하세요 : /content/gdrive/MyDrive/DB
# 데이터 로딩중
# 패키지를 로딩할게요
# 예측 라벨링 중...
# 걸린시간 :  10.271285057067871
# 어디에 저장할까요?
# 파일 경로
# /content/gdrive/MyDrive
# 파일 이름
# T140128-00703_0
