# %% [markdown]
# # import

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
evt_opt = pd.read_csv('../DATA_JOIN/EVENT_JOIN_OPTIME.csv')

data = pd.read_csv('../csv/DATA.csv')

# %%
evt_opt.head()
# Out:
#         Unnamed: 0 TAG_NAME DEVICE_NAME           OCCUR_TIME  M_CODE  \
# 0                0      NaN         NaN  2020-09-18 07:33:00     4.0
# 1                1      NaN        ANU1  2020-09-18 07:33:02    10.0
# 2                2      NaN        TSU1  2020-09-18 07:33:08    10.0
# 3                3      NaN         NaN  2020-09-18 07:36:13     5.0
# 4                4      NaN         NaN  2019-07-24 07:26:30     4.0
# ...            ...      ...         ...                  ...     ...
# 312788      312788      NaN        REC2  2022-02-11 19:34:51    10.0
# 312789      312789      NaN        TSU1  2022-02-11 20:40:05    10.0
# 312790      312790      NaN        REC2  2022-02-11 20:40:23    10.0
# 312791      312791      NaN        REC1  2022-02-11 20:40:25    10.0
# 312792      312792      NaN        REC3  2022-02-11 20:40:27    10.0
#
#         ERR_CODE                DESCRIPT  VALUE  LOG_LEVEL ACK_TIME  ...  \
# ...

# %%
data
# Out:
#         OP_INDEX  DATA_INDEX        DATA_TIME    CSU    STS    FTS      FMU  \
# 0              1           1    2020.7.9 1:50  44.80   0.00   0.00   488.36
# 1              1           1   2018.3.14 9:58  33.55  10.21  37.16  3293.63
# 2              1           1    2020.5.4 2:45  45.31   0.00  36.07  3136.53
# 3              1           1   2021.5.29 4:26   0.00   0.00   0.00  3524.26
# 4              1           1  2021.8.12 10:42  45.42  26.95  28.02  2712.63
# ...          ...         ...              ...    ...    ...    ...      ...
# 583067      1075          15    2021.3.4 3:48  35.72   0.00  31.84   629.44
# 583068      1075          16    2021.3.4 3:49  35.70   0.00  31.86   630.25
# 583069      1075          17    2021.3.4 3:50  35.69   0.00  31.83   633.15
# 583070      1075          18    2021.3.4 3:51  35.68   0.00  31.86   629.84
# 583071      1075          19    2021.3.4 3:52  35.68   0.00  31.85   630.79
#
# ...

# %%
evt_opt['OCCUR_TIME'] = evt_opt['OCCUR_TIME'].astype('datetime64')
data['DATA_TIME'] = data['DATA_TIME'].astype('datetime64')

# %%
evt_opt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312793 entries, 0 to 312792
# Data columns (total 39 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    312793 non-null  int64
#  1   TAG_NAME      24917 non-null   object
#  2   DEVICE_NAME   271643 non-null  object
#  3   OCCUR_TIME    312793 non-null  datetime64[ns]
#  4   M_CODE        311302 non-null  float64
#  5   ERR_CODE      312793 non-null  int64
#  6   DESCRIPT      312793 non-null  object
#  7   VALUE         312793 non-null  float64
#  8   LOG_LEVEL     312793 non-null  int64
#  9   ACK_TIME      8111 non-null    object
#  10  RESET_TIME    8460 non-null    object
#  11  ISCLEAR       312793 non-null  int64
#  12  SIMUL         312793 non-null  int64
#  13  EVENT_INDEX   312793 non-null  int64
#  14  KEY           312793 non-null  object
#  15  SHIP_ID       312793 non-null  object
#  16  SYSTEM        312793 non-null  int64
# ...

# %%
extract_list=['year', 'month', 'day', 'hour', 'minute']
year_list=[]
month_list=[]



evt_opt['OCCUR_TIME'][i].year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 extract_list=[year, ]
#       3 evt_opt['OCCUR_TIME'][i].year
#
# NameError: name 'year' is not defined
