# %% [markdown]
# # M_code별로 그룹핑

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
evt = pd.read_csv(('../../../Work/techcross/csv/EVENT.csv'))

# %%
#M_CODE의 null 99999로 대체

evt['M_CODE'].fillna(99999, inplace=True)

# %%
#M_CODE 개수 구하기

mcodelist = evt['M_CODE'].unique().tolist()
len(mcodelist)
# Out:
# 107

# %%
mcodelist
# Out:
# [50.0,
#  0.0,
#  52.0,
#  5.0,
#  3.0,
#  703.0,
#  405.0,
#  303.0,
#  11.0,
#  2.0,
#  304.0,
#  773.0,
#  4.0,
#  53.0,
#  91.0,
#  301.0,
#  10.0,
#  51.0,
#  302.0,
#  701.0,
#  94.0,
#  8.0,
#  99999.0,
#  5001.0,
#  9.0,
#  90.0,
#  305.0,
#  724.0,
#  81.0,
#  606.0,
#  202.0,
#  406.0,
#  401.0,
#  410.0,
#  200.0,
#  127.0,
#  80.0,
#  23.0,
#  93.0,
#  95.0,
#  604.0,
#  161.0,
#  603.0,
#  201.0,
#  605.0,
#  306.0,
#  220.0,
#  92.0,
#  400.0,
#  732.0,
#  775.0,
#  21.0,
#  5005.0,
#  5007.0,
#  706.0,
#  105.0,
#  5004.0,
#  250.0,
#  260.0,
#  709.0,
#  412.0,
#  96.0,
#  98.0,
#  728.0,
#  607.0,
#  774.0,
#  5011.0,
#  501.0,
#  734.0,
#  83.0,
#  150.0,
#  5009.0,
#  123.0,
#  129.0,
#  502.0,
#  145.0,
#  601.0,
#  210.0,
#  710.0,
#  505.0,
#  414.0,
#  717.0,
#  130.0,
#  203.0,
#  152.0,
#  82.0,
#  778.0,
#  503.0,
#  800.0,
#  413.0,
#  750.0,
#  240.0,
#  97.0,
#  99.0,
#  249.0,
#  5003.0,
#  609.0,
#  5008.0,
#  300.0,
#  771.0,
#  153.0,
#  5012.0,
# ...

# %%
for _ in range (0, len(mcodelist)):
    globals()["evt" + str(int(mcodelist[_]))] = evt[evt['M_CODE'] == mcodelist[_]]

# %%
evt5009
# Out:
#               SHIP_ID  SYSTEM  EVENT_INDEX         TAG_NAME DEVICE_NAME  \
# 8998    T140113-00103       0          261  MODULE6_SYS_ERR        REC3
# 9262    T140113-00103       0          269  MODULE6_SYS_ERR        REC3
# 9526    T140113-00103       0          277  MODULE6_SYS_ERR        REC3
# 66350   T140113-00104       0         2082  MODULE2_SYS_ERR        REC5
# 66380   T140113-00104       0         2083  MODULE3_SYS_ERR        REC4
# 83740   T140113-00103       0         2706  MODULE6_SYS_ERR        REC3
# 105888  T140113-00103       0         3643  MODULE6_SYS_ERR        REC3
# 128452  T140113-00103       0         4834  MODULE1_SYS_ERR        REC4
# 128468  T140113-00103       0         4835  MODULE4_SYS_ERR        REC4
# 128612  T140113-00103       0         4844  MODULE1_SYS_ERR        REC4
# 128660  T140113-00103       0         4847  MODULE4_SYS_ERR        REC4
# 153800  T140113-00103       0         6580  MODULE6_SYS_ERR        REC3
# ...
