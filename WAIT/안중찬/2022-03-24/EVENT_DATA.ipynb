# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnJungChan/TECHLOSS_SIGNLAB/blob/main/WAIT/%EC%95%88%EC%A4%91%EC%B0%AC/2022-03-24/EVENT_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 패키지 로딩

# %%
from google.colab import drive
drive.mount('/content/gdrive') 
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# # 데이터 로딩

# %% [markdown]
# ## DATA_DEVICE_JOIN_DATA_JOIN_OPTIME

# %%
DATA_DEVICE = pd.read_csv('/content/gdrive/MyDrive/DB/DATA_DEVICE.csv')
ANU = pd.read_csv('/content/gdrive/MyDrive/DB/ANU.csv')
ECU = pd.read_csv('/content/gdrive/MyDrive/DB/ECU.csv')
PMU = pd.read_csv('/content/gdrive/MyDrive/DB/PMU.csv')
TSU = pd.read_csv('/content/gdrive/MyDrive/DB/TSU.csv')
DATA = pd.read_csv('/content/gdrive/MyDrive/DB/DATA.csv')
DATA_DEVICE['DDKEY'] = DATA_DEVICE['SHIP_ID'] + "_" + DATA_DEVICE['SECTION'].astype(str) + "_" + DATA_DEVICE['D_INDEX'].astype(str) + "_" + DATA_DEVICE['DEVICE_ID'].astype(str) + "_" +DATA_DEVICE['DEVICETYPE'].astype(str)
ECU['DEVICETYPE'] = 1
ANU['DEVICETYPE'] = 2
TSU['DEVICETYPE'] = 3
PMU['DEVICETYPE'] = 4
ECU['DDKEY'] = ECU['SHIP_ID'] + "_" + ECU['SECTION'].astype(str) + "_" + ECU['D_INDEX'].astype(str) + "_" + ECU['DEVICE_ID'].astype(str) + "_" +ECU['DEVICETYPE'].astype(str)
ANU['DDKEY'] = ANU['SHIP_ID'] + "_" + ANU['SECTION'].astype(str) + "_" + ANU['D_INDEX'].astype(str) + "_" + ANU['DEVICE_ID'].astype(str) + "_" +ANU['DEVICETYPE'].astype(str)
TSU['DDKEY'] = TSU['SHIP_ID'] + "_" + TSU['SECTION'].astype(str) + "_" + TSU['D_INDEX'].astype(str) + "_" + TSU['DEVICE_ID'].astype(str) + "_" +TSU['DEVICETYPE'].astype(str)
PMU['DDKEY'] = PMU['SHIP_ID'] + "_" + PMU['SECTION'].astype(str) + "_" + PMU['D_INDEX'].astype(str) + "_" + PMU['DEVICE_ID'].astype(str) + "_" +PMU['DEVICETYPE'].astype(str)
ECU.rename(columns = lambda x: "ECU_" + x, inplace = True)
ANU.rename(columns = lambda x: "ANU_" + x, inplace = True)
TSU.rename(columns = lambda x: "TSU_" + x, inplace = True)
PMU.rename(columns = lambda x: "PMU_" + x, inplace = True)
ECU.rename(columns = {'ECU_DDKEY' : 'DDKEY'},inplace=True)
ANU.rename(columns = {'ANU_DDKEY' : 'DDKEY'},inplace=True)
TSU.rename(columns = {'TSU_DDKEY' : 'DDKEY'},inplace=True)
PMU.rename(columns = {'PMU_DDKEY' : 'DDKEY'},inplace=True)
DDECU=pd.merge(DATA_DEVICE,ECU,how = 'left', on = 'DDKEY')
DDANU=pd.merge(DATA_DEVICE,ANU,how = 'left', on = 'DDKEY')
DDPMU=pd.merge(DATA_DEVICE,PMU,how = 'left', on = 'DDKEY')
DDTSU=pd.merge(DATA_DEVICE,TSU,how = 'left', on = 'DDKEY')
DDECU.drop(columns = ['ECU_SHIP_ID','ECU_D_INDEX','ECU_DEVICE_ID','ECU_SYSTEM','ECU_SECTION','ECU_DEVICETYPE'],inplace = True)
DDANU.drop(columns = ['ANU_SHIP_ID','ANU_D_INDEX','ANU_DEVICE_ID','ANU_SYSTEM','ANU_SECTION','ANU_DEVICETYPE'],inplace = True)
DDPMU.drop(columns = ['PMU_SHIP_ID','PMU_D_INDEX','PMU_DEVICE_ID','PMU_SYSTEM','PMU_SECTION','PMU_DEVICETYPE'],inplace = True)
DDTSU.drop(columns = ['TSU_SHIP_ID','TSU_D_INDEX','TSU_DEVICE_ID','TSU_SYSTEM','TSU_SECTION','TSU_DEVICETYPE'],inplace = True)
DDANU.drop(columns = ['DATA_INDEX', 'OP_INDEX', 'DEVICETYPE','DEVICE_ID','D_INDEX','SHIP_ID','SYSTEM','SECTION','DDKEY'],inplace = True)
DDPMU.drop(columns = ['DATA_INDEX', 'OP_INDEX', 'DEVICETYPE','DEVICE_ID','D_INDEX','SHIP_ID','SYSTEM','SECTION','DDKEY'],inplace = True)
DDTSU.drop(columns = ['DATA_INDEX', 'OP_INDEX', 'DEVICETYPE','DEVICE_ID','D_INDEX','SHIP_ID','SYSTEM','SECTION','DDKEY'],inplace = True)
DATA_DEVICE_TYPE=pd.concat([DDECU,DDANU,DDTSU,DDPMU],axis = 1)
DATA_DEVICE_TYPE.drop(columns = ['DDKEY'],inplace = True)
DATA_DEVICE_TYPE['KEY'] = DATA_DEVICE_TYPE['SHIP_ID'] + "_" + DATA_DEVICE_TYPE['SECTION'].astype(str) + "_" + DATA_DEVICE_TYPE['OP_INDEX'].astype(str) + "_" + DATA_DEVICE_TYPE['DATA_INDEX'].astype(str)
DATA['KEY'] = DATA['SHIP_ID'] + "_" + DATA['SECTION'].astype(str) + "_" + DATA['OP_INDEX'].astype(str) + "_" + DATA['DATA_INDEX'].astype(str)
DATA.drop(columns = ['OP_INDEX','DATA_INDEX','SHIP_ID','SYSTEM', 'SECTION'],inplace = True)
DATA_DEVICE_JOIN_DATA=pd.merge(DATA_DEVICE_TYPE,DATA,how = 'left', on = 'KEY')
DATA_DEVICE_JOIN_DATA.drop(columns = ['KEY'], inplace = True)
OPTIME = pd.read_csv('/content/gdrive/MyDrive/DB/OPTIME.csv')
DATA_DEVICE_JOIN_DATA['KEY'] = DATA_DEVICE_JOIN_DATA['SHIP_ID'] + "_" + DATA_DEVICE_JOIN_DATA['SECTION'].astype(str) + "_" + DATA_DEVICE_JOIN_DATA['OP_INDEX'].astype(str)
OPTIME['KEY'] = OPTIME['SHIP_ID'] + "_" + OPTIME['SECTION'].astype(str) + "_" + OPTIME['OP_INDEX'].astype(str)
OPTIME.drop(columns = ['SHIP_ID', 'SECTION', 'OP_INDEX','SYSTEM'], inplace = True)
DATA_DEVICE_JOIN_DATA_JOIN_OPTIME=pd.merge(DATA_DEVICE_JOIN_DATA,OPTIME,how = 'left', on = 'KEY')
DATA_DEVICE_JOIN_DATA_JOIN_OPTIME.drop(columns = ['KEY'], inplace = True)
DATA_DEVICE_JOIN_DATA_JOIN_OPTIME
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
#          DATA_INDEX  OP_INDEX  DEVICETYPE  DEVICE_ID  D_INDEX        SHIP_ID  \
# 0                 1         1           1          1        1  T140113-00101
# 1                 1         1           1          1        1  T140113-00102
# 2                 1         1           1          1        1  T140113-00104
# 3                 1         1           1          1        1  T140128-00703
# 4                 1         1           1          1        1  T140703-00101
# ...             ...       ...         ...        ...      ...            ...
# 2134652        5619       186           1          2    39824  T140110-00206
# 2134653        5619       186           3          1    44491  T140110-00206
# 2134654        5620       186           1          1    39825  T140110-00206
# ...

# %% [markdown]
# # EVENT_JOIN_OPTIME

# %%
EVENT = pd.read_csv('/content/gdrive/MyDrive/DB/EVENT.csv')
OPTIME = pd.read_csv('/content/gdrive/MyDrive/DB/OPTIME.csv')
OPTIME_EVENT = pd.read_csv('/content/gdrive/MyDrive/DB/OPTIME_EVENT.csv')
EVENT['SECTION']=EVENT['SECTION'].astype('str')
EVENT['EVENT_INDEX'] = EVENT['EVENT_INDEX'].astype('str')
OPTIME_EVENT['SECTION']=OPTIME_EVENT['SECTION'].astype('str')
OPTIME_EVENT['EVENT_INDEX'] = OPTIME_EVENT['EVENT_INDEX'].astype('str')
EVENT['KEY']=EVENT['SHIP_ID']+"_"+ EVENT['SECTION']+"_"+ EVENT['EVENT_INDEX']
OPTIME_EVENT['KEY']=OPTIME_EVENT['SHIP_ID']+"_"+ OPTIME_EVENT['SECTION']+"_"+ OPTIME_EVENT['EVENT_INDEX']
EVENT_JOIN_OPTIME_EVENT = pd.merge(EVENT, OPTIME_EVENT, how = "inner", on = "KEY")
EVENT_JOIN_OPTIME_EVENT.drop(columns = ["SHIP_ID_x", "SYSTEM_x", "EVENT_INDEX_x", "SECTION_x"],inplace = True)
EVENT_JOIN_OPTIME_EVENT.rename(columns = {'SHIP_ID_y' : 'SHIP_ID', 'EVENT_INDEX_y':'EVENT_INDEX', 'SYSTEM_y' : 'SYSTEM', 'SECTION_y' : 'SECTION'}, inplace = True)
EVENT_JOIN_OPTIME_EVENT.drop(columns = ["KEY"],inplace = True)
EVENT_JOIN_OPTIME_EVENT['KEY'] = EVENT_JOIN_OPTIME_EVENT['SHIP_ID']+"_"+  EVENT_JOIN_OPTIME_EVENT['SECTION'].astype('str')+"_"+  EVENT_JOIN_OPTIME_EVENT['OP_INDEX'].astype('str')
OPTIME['KEY'] = OPTIME['SHIP_ID']+"_"+  OPTIME['SECTION'].astype('str')+"_"+  OPTIME['OP_INDEX'].astype('str')
EVENT_JOIN_OPTIME = pd.merge(EVENT_JOIN_OPTIME_EVENT, OPTIME, how = "inner", on = "KEY")
EVENT_JOIN_OPTIME.drop(columns = ["SHIP_ID_x", "SYSTEM_x", "SECTION_x",'FILE_INDEX_x','OP_INDEX_x'],inplace = True)
EVENT_JOIN_OPTIME.rename(columns = {'SHIP_ID_y' : 'SHIP_ID', 'OP_INDEX_y':'OP_INDEX', 'SYSTEM_y' : 'SYSTEM', 'SECTION_y' : 'SECTION', 'FILE_INDEX_y':'FILE_INDEX'}, inplace = True)

# %% [markdown]
# # EVENT를 DATA에 부착시킬 수 있는가?
#
# - EVENT_JOIN_OPTIME 테이블과 DATA_DEVICE_JOIN_DATA_JOIN_OPTIME 테이블의 공통 테이블인 OPTIME 테이블을 가지고 부착을 시켜본다.
#
# - DATA_DEVICE_JOIN_OPTIME_DATA 테이블은 1분 단위로 올라오는 테이블이다.
#
# - OPTIME별로 하나씩 해결해보고, 그 이후에 일반화 시키는 작업을 거친다.

# %% [markdown]
# #

# %%
print("EVENT테이블의 SHIP_ID갯수 :", len(EVENT_JOIN_OPTIME['SHIP_ID'].unique()))
print("DATA테이블의 SHIP_ID갯수  :", len(DATA_DEVICE_JOIN_DATA_JOIN_OPTIME['SHIP_ID'].unique()))
# Out:
# EVENT테이블의 SHIP_ID갯수 : 34
# DATA테이블의 SHIP_ID갯수  : 36

# %% [markdown]
# 두 경우의 SHIP_ID 갯수가 다르다는 사실을 확인하였고, 우리가 실질적으로 다룰 수 있는 것은 34개의 호선뿐이다. <br>
#
# 이 때, 2개 차이가 나는 것은 unknownship이 event 테이블엔 없기 때문이다.(알수 없는 배의 갯수가 2개임!)

# %%
EVENT = EVENT_JOIN_OPTIME
DATA = DATA_DEVICE_JOIN_DATA_JOIN_OPTIME

# %% [markdown]
# 테이블 이름이 길어서 다시 테이블을 세팅한다.

# %% [markdown]
# # SHIP_ID, OP_INDEX의 종류
#
# - 각각을 하나씩 뜯어서 line plot을 그릴것이기 때문에, ship_id, op_index의 종류를 파악하였다.

# %%
EVENT[['SHIP_ID', 'OP_INDEX']].drop_duplicates().sort_values(by = ["SHIP_ID","OP_INDEX"])
# Out:
#              SHIP_ID  OP_INDEX
# 26     T140110-00206         1
# 79     T140110-00206         2
# 87     T140110-00206         3
# 131    T140110-00206         4
# 364    T140110-00206         5
# ...              ...       ...
# 26010   T20210521011        98
# 26080   T20210521011        99
# 26112   T20210521011       100
# 26160   T20210521011       101
# 26193   T20210521011       102
#
# [9588 rows x 2 columns]

# %% [markdown]
# # 프로토타입 생성

# %% [markdown]
# ## T140110-00206
#
# - 오퍼레이션이 761번 발생

# %% [markdown]
# ### 1번 오퍼레이션

# %%
EVENT.loc[(EVENT['SHIP_ID'] == "T140110-00206") & (EVENT['OP_INDEX'] == 1),:]['LINE']
# Out:
# 26    2
# 27    2
# 28    2
# 29    2
# 30    2
# 31    2
# 32    2
# 33    2
# 34    2
# Name: LINE, dtype: int64

# %%
DATA.loc[(DATA['SHIP_ID'] == "T140110-00206") & (DATA['OP_INDEX'] == 1),:][['SECTION','DEVICE_ID','ECU_CURRENT','ECU_CONTROL_CURRENT']]
# Out:
#        SECTION  DEVICE_ID  ECU_CURRENT  ECU_CONTROL_CURRENT
# 26           0          3          0.0                 -1.0
# 37           0          4          0.0                 -1.0
# 75           0          1          NaN                  NaN
# 106          0          1          NaN                  NaN
# 51765        0          3        554.0                 -1.0
# 51774        0          4       1107.0                 -1.0
# 51810        0          1          NaN                  NaN
# 51836        0          1          NaN                  NaN
# 86346        0          3        554.0                 -1.0
# 86354        0          4       1108.0                 -1.0
# 86386        0          1          NaN                  NaN
# 86409        0          1          NaN                  NaN

# %% [markdown]
# #### EVENT 발생 파악

# %%
EF=EVENT.loc[(EVENT['SHIP_ID'] == "T140110-00206") & (EVENT['OP_INDEX'] == 1),:][["DEVICE_NAME","OCCUR_TIME","DESCRIPT"]]
EF["DESCRIPT"]="["+EF["DEVICE_NAME"].fillna("") + "]" + EF["DESCRIPT"]
EF=EF.drop(columns = "DEVICE_NAME")
# Out:
# 9

# %% [markdown]
# #### DATA_TIME에 따른 DATA값들의 움직임 파악
#
# - CSU, FMU, ECU, TSU, FMU, ANU, TSU

# %%
DF=DATA.loc[(DATA['SHIP_ID'] == "T140110-00206") & (DATA['OP_INDEX'] == 1),:][["DATA_TIME","CSU","FMU","CURRENT","VOLTAGE", "TRO","ANU","START_TIME","END_TIME"]]
DF["DATA_TIME"] = DF["DATA_TIME"].astype("datetime64")
DF
# Out:
#                 DATA_TIME    CSU     FMU  CURRENT  VOLTAGE  TRO  ANU  \
# 26    2020-07-09 01:50:34  44.80  488.36        0      0.0  0.0  0.0
# 37    2020-07-09 01:50:34  44.80  488.36        0      0.0  0.0  0.0
# 75    2020-07-09 01:50:34  44.80  488.36        0      0.0  0.0  0.0
# 106   2020-07-09 01:50:34  44.80  488.36        0      0.0  0.0  0.0
# 51765 2020-07-09 01:51:34  44.60  488.91     1661      4.1  0.0  0.0
# 51774 2020-07-09 01:51:34  44.60  488.91     1661      4.1  0.0  0.0
# 51810 2020-07-09 01:51:34  44.60  488.91     1661      4.1  0.0  0.0
# 51836 2020-07-09 01:51:34  44.60  488.91     1661      4.1  0.0  0.0
# 86346 2020-07-09 01:52:34  44.67  487.55     1662      4.1  0.0  0.0
# 86354 2020-07-09 01:52:34  44.67  487.55     1662      4.1  0.0  0.0
# 86386 2020-07-09 01:52:34  44.67  487.55     1662      4.1  0.0  0.0
# 86409 2020-07-09 01:52:34  44.67  487.55     1662      4.1  0.0  0.0
#
#                 START_TIME             END_TIME
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "CSU", markers= True, title = "CSU")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "FMU", markers= True, title = "FMU")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
  fig.add_annotation(x = EF['OCCUR_TIME'].iloc[i], y = np.max(DF["FMU"]), text = EF['DESCRIPT'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "CURRENT", markers=True, title = "CURRENT")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "VOLTAGE", markers=True, title = "VOLTAGE")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "TRO", markers=True, title = "TRO")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
  fig.add_annotation(x = EF['OCCUR_TIME'].iloc[i], y = np.max(DF["TRO"]), text = EF['DESCRIPT'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(DF, x = "DATA_TIME", y = "ANU", markers=True, title = "ANU")
for i in range(len(EF)) : 
  fig.add_vline(EF['OCCUR_TIME'].iloc[i])
  fig.add_annotation(x = EF['OCCUR_TIME'].iloc[i], y = np.max(DF["ANU"]), text = EF['DESCRIPT'].iloc[i])
fig.update_xaxes(range = [DF['START_TIME'].unique().astype("datetime64"),DF['END_TIME'].unique().astype("datetime64")])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
